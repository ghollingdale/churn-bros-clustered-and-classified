# %%
# Import libaries
import pandas as pd

import sys
sys.path.insert(0, '../')
import src.cleanup as cleanup

# %%
# Import csv as churners
churners = pd.read_csv('../data/BankChurners.csv')

# %%
# Drop unnecessary coulmns from csv and resave
churners = cleanup.drop_column(churners, ['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2' ])

# %%
# Get dummies for target column
churners = cleanup.dummies(churners, ['Attrition_Flag'])

# %%
# Move encoded columns
churners = cleanup.move_column(churners, 'Attrition_Flag_Attrited Customer', 3)
display(churners)
# Out:
#        CLIENTNUM  Customer_Age Gender  Attrition_Flag_Attrited Customer  \
# 0      768805383            45      M                             False
# 1      818770008            49      F                             False
# 2      713982108            51      M                             False
# 3      769911858            40      F                             False
# 4      709106358            40      M                             False
# ...          ...           ...    ...                               ...
# 10122  772366833            50      M                             False
# 10123  710638233            41      M                              True
# 10124  716506083            44      F                              True
# 10125  717406983            30      M                              True
# 10126  714337233            43      F                              True
#
#        Dependent_count Education_Level Marital_Status Income_Category  \
# 0                    3     High School        Married     $60K - $80K
# 1                    5        Graduate         Single  Less than $40K
# 2                    3        Graduate        Married    $80K - $120K
# 3                    4     High School        Unknown  Less than $40K
# 4                    3      Uneducated        Married     $60K - $80K
# ...                ...             ...            ...             ...
# 10122                2        Graduate         Single     $40K - $60K
# 10123                2         Unknown       Divorced     $40K - $60K
# 10124                1     High School        Married  Less than $40K
# 10125                2        Graduate        Unknown     $40K - $60K
# 10126                2        Graduate        Married  Less than $40K
#
#       Card_Category  Months_on_book  ...  Contacts_Count_12_mon  Credit_Limit  \
# 0              Blue              39  ...                      3       12691.0
# 1              Blue              44  ...                      2        8256.0
# 2              Blue              36  ...                      0        3418.0
# 3              Blue              34  ...                      1        3313.0
# 4              Blue              21  ...                      0        4716.0
# ...             ...             ...  ...                    ...           ...
# 10122          Blue              40  ...                      3        4003.0
# 10123          Blue              25  ...                      3        4277.0
# 10124          Blue              36  ...                      4        5409.0
# 10125          Blue              36  ...                      3        5281.0
# 10126        Silver              25  ...                      4       10388.0
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                      777          11914.0                 1.335
# 1                      864           7392.0                 1.541
# 2                        0           3418.0                 2.594
# 3                     2517            796.0                 1.405
# 4                        0           4716.0                 2.175
# ...                    ...              ...                   ...
# 10122                 1851           2152.0                 0.703
# 10123                 2186           2091.0                 0.804
# 10124                    0           5409.0                 0.819
# 10125                    0           5281.0                 0.535
# 10126                 1961           8427.0                 0.703
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1144              42                1.625
# 1                 1291              33                3.714
# 2                 1887              20                2.333
# 3                 1171              20                2.333
# 4                  816              28                2.500
# ...                ...             ...                  ...
# 10122            15476             117                0.857
# 10123             8764              69                0.683
# 10124            10291              60                0.818
# 10125             8395              62                0.722
# 10126            10294              61                0.649
#
#        Avg_Utilization_Ratio  Attrition_Flag_Existing Customer
# 0                      0.061                              True
# 1                      0.105                              True
# 2                      0.000                              True
# 3                      0.760                              True
# 4                      0.000                              True
# ...                      ...                               ...
# 10122                  0.462                              True
# 10123                  0.511                             False
# 10124                  0.000                             False
# 10125                  0.000                             False
# 10126                  0.189                             False
#
# [10127 rows x 22 columns]

# %%
new_path = '../data/churn_encoded.csv'
cleanup.save_csv(churners, new_path)
# Out:
#        CLIENTNUM  Customer_Age Gender  Attrition_Flag_Attrited Customer  \
# 0      768805383            45      M                             False
# 1      818770008            49      F                             False
# 2      713982108            51      M                             False
# 3      769911858            40      F                             False
# 4      709106358            40      M                             False
# ...          ...           ...    ...                               ...
# 10122  772366833            50      M                             False
# 10123  710638233            41      M                              True
# 10124  716506083            44      F                              True
# 10125  717406983            30      M                              True
# 10126  714337233            43      F                              True
#
#        Dependent_count Education_Level Marital_Status Income_Category  \
# 0                    3     High School        Married     $60K - $80K
# 1                    5        Graduate         Single  Less than $40K
# 2                    3        Graduate        Married    $80K - $120K
# 3                    4     High School        Unknown  Less than $40K
# 4                    3      Uneducated        Married     $60K - $80K
# ...                ...             ...            ...             ...
# 10122                2        Graduate         Single     $40K - $60K
# 10123                2         Unknown       Divorced     $40K - $60K
# 10124                1     High School        Married  Less than $40K
# 10125                2        Graduate        Unknown     $40K - $60K
# 10126                2        Graduate        Married  Less than $40K
#
#       Card_Category  Months_on_book  ...  Contacts_Count_12_mon  Credit_Limit  \
# 0              Blue              39  ...                      3       12691.0
# 1              Blue              44  ...                      2        8256.0
# 2              Blue              36  ...                      0        3418.0
# 3              Blue              34  ...                      1        3313.0
# 4              Blue              21  ...                      0        4716.0
# ...             ...             ...  ...                    ...           ...
# 10122          Blue              40  ...                      3        4003.0
# 10123          Blue              25  ...                      3        4277.0
# 10124          Blue              36  ...                      4        5409.0
# 10125          Blue              36  ...                      3        5281.0
# 10126        Silver              25  ...                      4       10388.0
#
#        Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0                      777          11914.0                 1.335
# 1                      864           7392.0                 1.541
# 2                        0           3418.0                 2.594
# 3                     2517            796.0                 1.405
# 4                        0           4716.0                 2.175
# ...                    ...              ...                   ...
# 10122                 1851           2152.0                 0.703
# 10123                 2186           2091.0                 0.804
# 10124                    0           5409.0                 0.819
# 10125                    0           5281.0                 0.535
# 10126                 1961           8427.0                 0.703
#
#        Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1144              42                1.625
# 1                 1291              33                3.714
# 2                 1887              20                2.333
# 3                 1171              20                2.333
# 4                  816              28                2.500
# ...                ...             ...                  ...
# 10122            15476             117                0.857
# 10123             8764              69                0.683
# 10124            10291              60                0.818
# 10125             8395              62                0.722
# 10126            10294              61                0.649
#
#        Avg_Utilization_Ratio  Attrition_Flag_Existing Customer
# 0                      0.061                              True
# 1                      0.105                              True
# 2                      0.000                              True
# 3                      0.760                              True
# 4                      0.000                              True
# ...                      ...                               ...
# 10122                  0.462                              True
# 10123                  0.511                             False
# 10124                  0.000                             False
# 10125                  0.000                             False
# 10126                  0.189                             False
#
# [10127 rows x 22 columns]
