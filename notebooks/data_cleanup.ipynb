# %%
# %load_ext autoreload
# %autoreload 2

# Import libaries
import pandas as pd

import sys
sys.path.insert(0, '../')
import src.cleanup as cleanup

# %%
# Import csv as churners
churners = pd.read_csv('../data/BankChurners.csv')
churners.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
# Drop unnecessary coulmns from csv
churners = cleanup.drop_column(churners, ['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1','Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2' ])

# %%
# Check for null data
print(churners.isnull().sum())
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# Get dummies for target column
# column_name must be a list
churners = cleanup.dummies(churners, 'Attrition_Flag')
churners.head()
# Out:
#    CLIENTNUM  Customer_Age Gender  Dependent_count Education_Level  \
# 0  768805383            45      M                3     High School
# 1  818770008            49      F                5        Graduate
# 2  713982108            51      M                3        Graduate
# 3  769911858            40      F                4     High School
# 4  709106358            40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  \
# 0        Married     $60K - $80K          Blue              39
# 1         Single  Less than $40K          Blue              44
# 2        Married    $80K - $120K          Blue              36
# 3        Unknown  Less than $40K          Blue              34
# 4        Married     $60K - $80K          Blue              21
#
#    Total_Relationship_Count  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                         5  ...       12691.0                  777
# ...

# %%
# Move encoded columns
churners = cleanup.move_column(churners, 'Attrition_Flag_Attrited Customer', 1)
display(churners)
# Out:
#        CLIENTNUM  Attrition_Flag_Attrited Customer  Customer_Age Gender  \
# 0      768805383                             False            45      M
# 1      818770008                             False            49      F
# 2      713982108                             False            51      M
# 3      769911858                             False            40      F
# 4      709106358                             False            40      M
# ...          ...                               ...           ...    ...
# 10122  772366833                             False            50      M
# 10123  710638233                              True            41      M
# 10124  716506083                              True            44      F
# 10125  717406983                              True            30      M
# 10126  714337233                              True            43      F
#
#        Dependent_count Education_Level Marital_Status Income_Category  \
# ...

# %%
# Rename attrited column
churners = cleanup.column_rename(churners, 'Attrition_Flag_Attrited Customer','Attrited')
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age Gender  Dependent_count  \
# 0      768805383     False            45      M                3
# 1      818770008     False            49      F                5
# 2      713982108     False            51      M                3
# 3      769911858     False            40      F                4
# 4      709106358     False            40      M                3
# ...          ...       ...           ...    ...              ...
# 10122  772366833     False            50      M                2
# 10123  710638233      True            41      M                2
# 10124  716506083      True            44      F                1
# 10125  717406983      True            30      M                2
# 10126  714337233      True            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# ...

# %%
# Get dummies for gender column
churners = cleanup.dummies(churners, 'Gender')
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count Education_Level  \
# 0      768805383     False            45                3     High School
# 1      818770008     False            49                5        Graduate
# 2      713982108     False            51                3        Graduate
# 3      769911858     False            40                4     High School
# 4      709106358     False            40                3      Uneducated
# ...          ...       ...           ...              ...             ...
# 10122  772366833     False            50                2        Graduate
# 10123  710638233      True            41                2         Unknown
# 10124  716506083      True            44                1     High School
# 10125  717406983      True            30                2        Graduate
# 10126  714337233      True            43                2        Graduate
#
#       Marital_Status Income_Category Card_Category  Months_on_book  \
# ...

# %%
# Get dummies for marital status
churners = cleanup.dummies(churners, 'Marital_Status')
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count Education_Level  \
# 0      768805383     False            45                3     High School
# 1      818770008     False            49                5        Graduate
# 2      713982108     False            51                3        Graduate
# 3      769911858     False            40                4     High School
# 4      709106358     False            40                3      Uneducated
# ...          ...       ...           ...              ...             ...
# 10122  772366833     False            50                2        Graduate
# 10123  710638233      True            41                2         Unknown
# 10124  716506083      True            44                1     High School
# 10125  717406983      True            30                2        Graduate
# 10126  714337233      True            43                2        Graduate
#
#       Income_Category Card_Category  Months_on_book  Total_Relationship_Count  \
# ...

# %%
# Encode 'Education Level'
education_hierarchy = ['Unknown', 'Uneducated', 'High School', 'College', 'Graduate', 'Post-Graduate', 'Doctorate']
churners = cleanup.encode_ordinal(churners, 'Education_Level', education_hierarchy)
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0      768805383     False            45                3              2.0
# 1      818770008     False            49                5              4.0
# 2      713982108     False            51                3              4.0
# 3      769911858     False            40                4              2.0
# 4      709106358     False            40                3              1.0
# ...          ...       ...           ...              ...              ...
# 10122  772366833     False            50                2              4.0
# 10123  710638233      True            41                2              0.0
# 10124  716506083      True            44                1              2.0
# 10125  717406983      True            30                2              4.0
# 10126  714337233      True            43                2              4.0
#
# ...

# %%
# Encode Income_Category
income_hierarchy = ['Unknown', 'Less than $40K', '$40K - $60K', '$60K - $80K', '$80K - $120K', '$120K +']
churners = cleanup.encode_ordinal(churners, 'Income_Category', income_hierarchy)
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0      768805383     False            45                3              2.0
# 1      818770008     False            49                5              4.0
# 2      713982108     False            51                3              4.0
# 3      769911858     False            40                4              2.0
# 4      709106358     False            40                3              1.0
# ...          ...       ...           ...              ...              ...
# 10122  772366833     False            50                2              4.0
# 10123  710638233      True            41                2              0.0
# 10124  716506083      True            44                1              2.0
# 10125  717406983      True            30                2              4.0
# 10126  714337233      True            43                2              4.0
#
#        Income_Category Card_Category  Months_on_book  \
# ...

# %%
# Encode Card_Category
card_hierarchy = ['Blue', 'Silver', 'Gold', 'Platinum']
churners = cleanup.encode_ordinal(churners, 'Card_Category', card_hierarchy)
display(churners)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0      768805383     False            45                3              2.0
# 1      818770008     False            49                5              4.0
# 2      713982108     False            51                3              4.0
# 3      769911858     False            40                4              2.0
# 4      709106358     False            40                3              1.0
# ...          ...       ...           ...              ...              ...
# 10122  772366833     False            50                2              4.0
# 10123  710638233      True            41                2              0.0
# 10124  716506083      True            44                1              2.0
# 10125  717406983      True            30                2              4.0
# 10126  714337233      True            43                2              4.0
#
#        Income_Category  Card_Category  Months_on_book  \
# ...

# %%
# Change booleans to binary
churners = cleanup.replace_boolean(churners)
churners.head()
# Out:
#    CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0  768805383         0            45                3              2.0
# 1  818770008         0            49                5              4.0
# 2  713982108         0            51                3              4.0
# 3  769911858         0            40                4              2.0
# 4  709106358         0            40                3              1.0
#
#    Income_Category  Card_Category  Months_on_book  Total_Relationship_Count  \
# 0              3.0            0.0              39                         5
# 1              1.0            0.0              44                         6
# 2              4.0            0.0              36                         4
# 3              1.0            0.0              34                         3
# 4              3.0            0.0              21                         5
#
#    Months_Inactive_12_mon  ...  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# ...

# %%
# Columns are dropped to avoid collinearity

churners = cleanup.drop_column(churners, 'Gender_F')
churners = cleanup.drop_column(churners, 'Marital_Status_Unknown')
churners = cleanup.drop_column(churners, 'Attrition_Flag_Existing Customer')
churners.head()
# Out:
#    CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0  768805383         0            45                3              2.0
# 1  818770008         0            49                5              4.0
# 2  713982108         0            51                3              4.0
# 3  769911858         0            40                4              2.0
# 4  709106358         0            40                3              1.0
#
#    Income_Category  Card_Category  Months_on_book  Total_Relationship_Count  \
# 0              3.0            0.0              39                         5
# 1              1.0            0.0              44                         6
# 2              4.0            0.0              36                         4
# 3              1.0            0.0              34                         3
# 4              3.0            0.0              21                         5
#
#    Months_Inactive_12_mon  ...  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# ...

# %%
new_path = '../data/churn_encoded.csv'
cleanup.save_csv(churners, new_path)
# Out:
#        CLIENTNUM  Attrited  Customer_Age  Dependent_count  Education_Level  \
# 0      768805383         0            45                3              2.0
# 1      818770008         0            49                5              4.0
# 2      713982108         0            51                3              4.0
# 3      769911858         0            40                4              2.0
# 4      709106358         0            40                3              1.0
# ...          ...       ...           ...              ...              ...
# 10122  772366833         0            50                2              4.0
# 10123  710638233         1            41                2              0.0
# 10124  716506083         1            44                1              2.0
# 10125  717406983         1            30                2              4.0
# 10126  714337233         1            43                2              4.0
#
#        Income_Category  Card_Category  Months_on_book  \
# ...
